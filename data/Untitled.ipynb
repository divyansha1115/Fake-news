# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
df
# Out:
#       Unnamed: 0  label                                               text
# 0     11972.json      5  Building a wall on the U.S.-Mexico border will...
# 1     11685.json      1  Wisconsin is on pace to double the number of l...
# 2     11096.json      1  Says John McCain has done nothing to help the ...
# 3      5209.json      2  Suzanne Bonamici supports a plan that will cut...
# 4      9524.json      4  When asked by a reporter whether hes at the ce...
# 5      5962.json      5  Over the past five years the federal governmen...
# 6      7070.json      5  Says that Tennessee law requires that schools ...
# 7      1046.json      0  Says Vice President Joe Biden "admits that the...
# 8     12849.json      5  Donald Trump is against marriage equality. He ...
# 9     13270.json      0  We know that more than half of Hillary Clinton...
# 10     6649.json      0  We know there are more Democrats in Georgia th...
# 11     2508.json      0  PolitiFact Texas says Congressman Edwards atta...
# 12    11269.json      4         Denali is the Kenyan word for black power.
# 13    11200.json      1  Says 57 percent of federal spending goes to th...
# 14     8047.json      2       On residency requirements for public workers
# 15     4888.json      5  Says the unemployment rate for college graduat...
# 16     3331.json      4  Unfortunately we have documented instances whe...
# 17     9198.json      2  A recent Gallup poll found that 72 percent of ...
# 18       73.json      5  Each year, 18,000 people die in America becaus...
# 19     1328.json      1  Ronald Reagan faced an even worse recession th...
# 20    12169.json      3  There have not been any public safety issues i...
# 21     5244.json      2  Says Mitt Romney was one of the first national...
# 22    12996.json      4  The number of illegal immigrants could be 3 mi...
# 23     8162.json      3              Marijuana is less toxic than alcohol.
# 24    10064.json      1  Says Charlie Crist is embroiled in a fraud cas...
# 25     1084.json      5  Now, there was a time when someone like Scalia...
# 26    13231.json      0  I was gone when there was a red line against S...
# 27    13089.json      2  Tim Kaine hiked tuition as governor, but now c...
# 28     1051.json      5  Contends that President Obama literally said (...
# 29     4161.json      3  Active duty males in the military are twice as...
# ...          ...    ...                                                ...
# 1237  11337.json      3  Says the cascading effects of climate change c...
# 1238   4250.json      4  Says state Rep. Sandy Pasch, her recall oppone...
# 1239    631.json      4  Barack Obama "rejects everyone white, includin...
# 1240   9351.json      4  A company hired to do Common Core testing in F...
# 1241   5746.json      5  The U.S. Supreme Court has not traditionally a...
# 1242   4136.json      2  Fracturing or horizontally fracturing the shal...
# 1243   1681.json      0  In 2004, "20 percent of U.S. households were g...
# 1244   5074.json      3  We are now eighth in the nation in job creatio...
# 1245   4195.json      0  In Europe, church attendance rates (are) in th...
# 1246   3931.json      0  Says George LeMieux even compared Marco Rubio ...
# 1247   4883.json      5  Says Barack Obama promised to halve the defici...
# 1248   6795.json      0  Says the government has gotten the TARP money ...
# 1249   9818.json      0  Points of Light is the worlds largest voluntee...
# 1250   8573.json      2  Says Mark Pryorcut Medicare to pay for Obamacare.
# 1251  13184.json      3  Says Tim Kaine actually tried to raise taxes b...
# 1252  11559.json      3  Says Marco Rubio is proposing a new $1 trillio...
# 1253   9241.json      5  I am the only senator who turned down the stat...
# 1254   8902.json      3                      Female buffalo lead the herd.
# 1255  12511.json      1  There is no system to vet refugees from the Mi...
# 1256   7285.json      4  Says Chris Christies plan to kick-start our ec...
# 1257   1005.json      4  Obama used $20 million in federal money to emm...
# 1258    609.json      2                              On offshore drilling.
# 1259   9436.json      0  We came out of the White House not only dead b...
# 1260   5671.json      1  I think its seven or eight of the California s...
# 1261   6699.json      4  Sen. Bob Menendez voted to enact a new tax on ...
# 1262   7334.json      2  Says his budget provides the highest state fun...
# 1263   9788.json      0                    Ive been here almost every day.
# 1264  10710.json      0  In the early 1980s, Sen. Edward Kennedy secret...
# 1265   3186.json      0  Says an EPA permit languished under Strickland...
# 1266   6743.json      1  Says the governor is going around the state ta...
#
# [1267 rows x 3 columns]

# %%
l=list(df['text'])

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

# %%
filt = []
stop_words = set(stopwords.words('english'))
for i in l:
    word_tokens = word_tokenize(i) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    words=[word.lower() for word in filtered_sentence if word.isalpha()]
    print(words)
    print('\n')
    filt.append(','.join(words))
# Out:
# ['building', 'wall', 'border', 'take', 'literally', 'years']
#
#
# ['wisconsin', 'pace', 'double', 'number', 'layoffs', 'year']
#
#
# ['says', 'john', 'mccain', 'done', 'nothing', 'help', 'vets']
#
#
# ['suzanne', 'bonamici', 'supports', 'plan', 'cut', 'choice', 'medicare', 'advantage', 'seniors']
#
#
# ['when', 'asked', 'reporter', 'whether', 'hes', 'center', 'criminal', 'scheme', 'violate', 'campaign', 'laws', 'gov', 'scott', 'walker', 'nodded', 'yes']
#
#
# ['over', 'past', 'five', 'years', 'federal', 'government', 'paid', 'million', 'retirement', 'disability', 'benefits', 'deceased', 'former', 'federal', 'employees']
#
#
# ['says', 'tennessee', 'law', 'requires', 'schools', 'receive', 'half', 'proceeds', 'million', 'per', 'year', 'increase', 'shelby', 'county', 'sales', 'tax']
#
#
# ['says', 'vice', 'president', 'joe', 'biden', 'admits', 'american', 'people', 'scammed', 'economic', 'stimulus', 'package']
#
#
# ['donald', 'trump', 'marriage', 'equality', 'he', 'wants', 'go', 'back']
#
#
# ['we', 'know', 'half', 'hillary', 'clintons', 'meetings', 'secretary', 'state', 'given', 'major', 'contributors', 'clinton', 'foundation']
#
#
# ['we', 'know', 'democrats', 'georgia', 'republicans', 'we', 'know', 'fact']
#
#
# ['politifact', 'texas', 'says', 'congressman', 'edwards', 'attacks', 'bill', 'flores', 'false']
#
#
# ['denali', 'kenyan', 'word', 'black', 'power']
#
#
# ['says', 'percent', 'federal', 'spending', 'goes', 'military', 'percent', 'goes', 'food', 'agriculture', 'including', 'food', 'stamps']
#
#
# ['on', 'residency', 'requirements', 'public', 'workers']
#
#
# ['says', 'unemployment', 'rate', 'college', 'graduates', 'percent', 'percent']
#
#
# ['unfortunately', 'documented', 'instances', 'people', 'defecated', 'statehouse', 'building']
#
#
# ['a', 'recent', 'gallup', 'poll', 'found', 'percent', 'americans', 'percent', 'democrats', 'say', 'biggest', 'threat', 'nations', 'security', 'big', 'government']
#
#
# ['each', 'year', 'people', 'die', 'america', 'health', 'care']
#
#
# ['ronald', 'reagan', 'faced', 'even', 'worse', 'recession', 'current', 'one']
#
#
# ['there', 'public', 'safety', 'issues', 'cities', 'allow', 'transgender', 'people', 'use', 'bathroom', 'gender', 'identify']
#
#
# ['says', 'mitt', 'romney', 'one', 'first', 'national', 'republican', 'leaders', 'endorse', 'marco', 'rubio']
#
#
# ['the', 'number', 'illegal', 'immigrants', 'could', 'million', 'it', 'could', 'million']
#
#
# ['marijuana', 'less', 'toxic', 'alcohol']
#
#
# ['says', 'charlie', 'crist', 'embroiled', 'fraud', 'case', 'steering', 'taxpayer', 'money', 'de', 'facto', 'ponzi', 'scheme']
#
#
# ['now', 'time', 'someone', 'like', 'scalia', 'ginsburg', 'got', 'votes']
#
#
# ['i', 'gone', 'red', 'line', 'syria']
#
#
# ['tim', 'kaine', 'hiked', 'tuition', 'governor', 'claims', 'champion', 'affordability']
#
#
# ['contends', 'president', 'obama', 'literally', 'said', 'proposals', 'pass', 'utility', 'rates', 'words', 'would', 'necessarily', 'skyrocket']
#
#
# ['active', 'duty', 'males', 'military', 'twice', 'likely', 'develop', 'prostate', 'cancer', 'civilian', 'counterparts']
#
#
# ['its', 'since', 'senate', 'different', 'party', 'president', 'white', 'house', 'confirmed', 'supreme', 'court', 'nominee']
#
#
# ['under', 'rosemary', 'lehmberg', 'travis', 'county', 'office', 'convened', 'grand', 'jury', 'indicted', 'rick', 'perry']
#
#
# ['on', 'team', 'hes', 'rooting', 'world', 'series']
#
#
# ['tom', 'ganley', 'two', 'fs', 'better', 'business', 'bureau', 'complaints', 'three', 'years']
#
#
# ['the', 'united', 'states', 'low', 'voter', 'turnout', 'rate']
#
#
# ['says', 'thomas', 'jefferson', 'said', 'you', 'might', 'able', 'fool', 'people', 'awhile', 'may', 'go', 'astray', 'sooner', 'later', 'american', 'people', 'going', 'wake', 'correct', 'course']
#
#
# ['because', 'federal', 'health', 'care', 'law', 'health', 'plans', 'canceled', 'florida']
#
#
# ['in', 'massachusetts', 'scott', 'brown', 'pushed', 'law', 'force', 'women', 'considering', 'abortion', 'force', 'look', 'color', 'photographs', 'developing', 'fetuses']
#
#
# ['the', 'fed', 'created', 'trillion', 'nothing', 'gave', 'banks', 'foreign', 'banks', 'could', 'stabilize', 'operations']
#
#
# ['texas', 'families', 'kept', 'billion', 'family', 'budgets', 'since', 'successfully', 'fought', 'restore', 'texas', 'sales', 'tax', 'deduction', 'decade', 'ago']
#
#
# ['conditions', 'covered', 'health', 'care', 'plan']
#
#
# ['greg', 'abbott', 'activated', 'state', 'guard', 'monitor', 'jade', 'helm', 'case', 'troops', 'try', 'impose', 'martial', 'law', 'disarm', 'innocent', 'texans', 'detain', 'tunnels', 'beneath', 'closed', 'walmart', 'stores']
#
#
# ['says', 'second', 'debate', 'hillary', 'clinton', 'landslide', 'every', 'poll']
#
#
# ['says', 'bag', 'litter', 'increased', 'san', 'francisco', 'banned', 'shopping', 'bags']
#
#
# ['in', 'newt', 'gingrich', 'first', 'advocated', 'individual', 'mandate', 'health', 'care', 'and', 'recently', 'may', 'year', 'still', 'advocating']
#
#
# ['says', 'result', 'national', 'health', 'care', 'reform', 'congressional', 'budget', 'office', 'says', 'save', 'million', 'first', 'years', 'over', 'next', 'years', 'save', 'trillion', 'savings', 'terms', 'health', 'care']
#
#
# ['you', 'said', 'would', 'vote', 'patriot', 'act', 'came', 'senate', 'voted']
#
#
# ['the', 'federal', 'minimum', 'wage', 'worth', 'percent', 'less', 'ronald', 'reagan', 'gave', 'first', 'address', 'joint', 'session', 'congress']
#
#
# ['a', 'proposed', 'tax', 'fund', 'transportation', 'projects', 'would', 'spend', 'take', 'single', 'vehicle', 'road', 'morning', 'afternoon', 'commute']
#
#
# ['a', 'salesclerk', 'hobby', 'lobby', 'needs', 'contraception', 'going', 'get', 'service', 'employers', 'health', 'care', 'plan', 'employer', 'doesnt', 'think', 'using', 'contraception']
#
#
# ['says', 'charlie', 'crist', 'voted', 'raising', 'minimum', 'wage']
#
#
# ['hillary', 'clinton', 'said', 'gun', 'confiscation', 'would', 'worth', 'considering']
#
#
# ['already', 'prototype', 'driverless', 'car', 'traveled', 'miles', 'crowded', 'maze', 'california', 'streets', 'without', 'single', 'accident']
#
#
# ['last', 'year', 'population', 'growth', 'state', 'texas', 'came', 'texas', 'states']
#
#
# ['when', 'undocumented', 'children', 'picked', 'border', 'told', 'appear', 'later', 'court', 'percent', 'show']
#
#
# ['says', 'gov', 'chris', 'christie', 'cut', 'spending', 'billion', 'provided', 'million', 'new', 'education', 'funding']
#
#
# ['hes', 'candidate', 'whos', 'balanced', 'budgets', 'brought', 'jobs', 'providence']
#
#
# ['studies', 'shown', 'absence', 'federal', 'reproductive', 'health', 'funds', 'going', 'see', 'level', 'abortion', 'georgia', 'increase', 'percent']
#
#
# ['acorn', 'paid', 'partner', 'census', 'bureau', 'charge', 'going', 'collecting', 'data', 'american', 'public']
#
#
# ['sixty', 'percent', 'hispanics', 'support', 'arizona', 'immigration', 'law']
#
#
# ['if', 'sequester', 'hits', 'federal', 'prosecutors', 'let', 'criminals', 'go']
#
#
# ['says', 'dick', 'cheney', 'iraqi', 'government', 'created', 'isis']
#
#
# ['says', 'bill', 'hillary', 'clinton', 'attended', 'donald', 'trumps', 'last', 'wedding']
#
#
# ['i', 'play', 'role', 'bringing', 'company', 'ri', 'others', 'government', 'i', 'tasked', 'handling', 'legislation', 'affecting', 'company', 'superiors']
#
#
# ['obamacare', 'insurance', 'cooperative', 'failures', 'expected', 'theyre', 'like', 'business', 'start', 'businesses', 'america', 'fifth', 'year', 'half', 'businesses', 'closed']
#
#
# ['the', 'tax', 'cut', 'deal', 'giving', 'billion', 'millionaires', 'billionaires']
#
#
# ['says', 'marco', 'rubio', 'said', 'social', 'security', 'medicare', 'haveweakened', 'us', 'people']
#
#
# ['across', 'country', 'billion', 'recovery', 'act', 'committed', 'first', 'days']
#
#
# ['as', 'secretary', 'department', 'energy', 'former', 'president', 'bill', 'clinton', 'i', 'created', 'reserves', 'home', 'heating', 'oil']
#
#
# ['states', 'lower', 'unemployment', 'texas', 'tied', 'mississippi', 'jobs', 'anywhere', 'united', 'states']
#
#
# ['of', 'bills', 'david', 'cicilline', 'sponsored', 'three', 'years', 'office', 'single', 'one', 'advanced', 'past', 'embryonic', 'committee', 'stage']
#
#
# ['says', 'donald', 'trump', 'said', 'loves', 'war', 'including', 'nukes']
#
#
# ['any', 'state', 'tax', 'law', 'start', 'house', 'renewal', 'state', 'hospital', 'bed', 'tax', 'year', 'started', 'senate', 'unconstitutional']
#
#
# ['every', 'child', 'born', 'today', 'inherits', 'share', 'national', 'debt', 'stands', 'trillion']
#
#
# ['a', 'strong', 'bipartisan', 'majority', 'house', 'representatives', 'voted', 'defund', 'obamacare']
#
#
# ['proximity', 'power', 'lines', 'lowers', 'property', 'values', 'much', 'percent']
#
#
# ['what', 'facts', 'say', 'best', 'scenario', 'kids', 'loving', 'mom', 'dad']
#
#
# ['says', 'mark', 'neumann', 'nancy', 'pelosi']
#
#
# ['to', 'hear', 'gov', 'christie', 'tell', 'everything', 'new', 'jersey', 'going', 'fine', 'well', 'i', 'see', 'another', 'new', 'jersey', 'unemployed', 'one', 'worst', 'jobless', 'rates', 'country', 'working', 'middle', 'class', 'families', 'seen', 'costs', 'soar', 'property', 'taxes', 'college', 'tuition']
#
#
# ['says', 'delegates', 'cant', 'legally', 'change', 'republican', 'national', 'convention', 'rules', 'prevent', 'donald', 'trumps', 'nomination']
#
#
# ['rebuilding', 'three', 'high', 'schools', 'benefit', 'percent', 'portland', 'public', 'school', 'students']
#
#
# ['proposition', 'novembers', 'texas', 'ballot', 'cost', 'state', 'taxpayers', 'money']
#
#
# ['providence', 'lowest', 'crime', 'rate', 'three', 'decades']
#
#
# ['on', 'banning', 'earmarks']
#
#
# ['says', 'hes', 'taken', 'pay', 'decrease', 'nine', 'years', 'office']
#
#
# ['percent', 'americans', 'millionaires', 'percent', 'house', 'millionaires', 'percent', 'senators', 'millionaires']
#
#
# ['the', 'decision', 'united', 'states', 'buy', 'heavy', 'water', 'iran', 'directly', 'subsidize', 'irans', 'nuclear', 'program']
#
#
# ['the', 'texas', 'department', 'transportation', 'misplaced', 'billion', 'dollars']
#
#
# ['a', 'judges', 'order', 'means', 'theres', 'constitution', 'exemption', 'zone', 'live', 'within', 'miles', 'united', 'states', 'border']
#
#
# ['pepper', 'kicked', 'jock', 'tax', 'imposing', 'levy', 'sports', 'entertainment', 'industry']
#
#
# ['mitch', 'mcconnell', 'opposed', 'legislation', 'create', 'protect', 'kentucky', 'jobs', 'help', 'unemployed', 'health', 'care', 'kentucky', 'children', 'fair', 'pay', 'women']
#
#
# ['under', 'mayor', 'tom', 'barrett', 'number', 'milwaukee', 'police', 'officers', 'increased']
#
#
# ['taxpayers', 'subsidize', 'percent', 'marta', 'trip']
#
#
# ['president', 'obama', 'harry', 'reid', 'nancy', 'pelosi', 'passed', 'trillion', 'stimulus', 'bill']
#
#
# ['says', 'milken', 'institute', 'rated', 'san', 'antonio', 'nations', 'local', 'economy']
#
#
# ['says', 'people', 'africa', 'literally', 'walk', 'two', 'three', 'hundred', 'miles', 'order', 'vote']
#
#
# ['before', 'world', 'war', 'ii', 'people', 'actually', 'health', 'insurance']
#
#
# ['half', 'children', 'struck', 'cars', 'near', 'schools', 'hit', 'parents', 'driving', 'children', 'school']
#
#
# ['citizens', 'property', 'insurance', 'billion', 'worth', 'risk', 'less', 'billion', 'worth', 'surplus']
#
#
# ['tom', 'leppert', 'pledged', 'make', 'dallas', 'sanctuary', 'city', 'illegal', 'immigrants']
#
#
# ['putting', 'three', 'republicans', 'cabinet', 'unprecedented']
#
#
# ['when', 'atlanta', 'police', 'chief', 'george', 'turner', 'interim', 'head', 'department', 'overall', 'crime', 'fell', 'percent', 'violent', 'crime', 'dropped', 'percent']
#
#
# ['from', 'top', 'percent', 'saw', 'income', 'go', 'roughly', 'percent', 'median', 'wage', 'country', 'years', 'went', 'percent']
#
#
# ['i', 'proud', 'governor', 'florida', 'signed', 'first', 'divestment', 'act', 'relates', 'iran', 'divesting', 'investments', 'companies', 'would', 'invest', 'iran']
#
#
# ['as', 'result', 'climate', 'change', 'ice', 'fishermen', 'wisconsin', 'already', 'noticing', 'fewer', 'days', 'ice', 'covered', 'lakes']
#
#
# ['muslim', 'nations', 'call', 'people', 'celebrated', 'attacks']
#
#
# ['says', 'donald', 'trump', 'said', 'women', 'and', 'tell', 'go', 'f']
#
#
# ['the', 'taliban', 'years', 'years', 'i', 'mean', 'hundreds', 'thousands', 'years']
#
#
# ['iran', 'president', 'hassan', 'rouhani', 'cabinet', 'members', 'american', 'universities', 'members', 'barack', 'obamas', 'cabinet']
#
#
# ['the', 'words', 'subhuman', 'mongrel', 'ted', 'nugent', 'called', 'president', 'barack', 'obama', 'used', 'nazis', 'justify', 'genocide', 'jewish', 'community']
#
#
# ['barack', 'obama', 'says', 'hes', 'going', 'reduce', 'debt', 'deficit', 'trillion', 'doesnt', 'say', 'hes', 'going']
#
#
# ['birth', 'control', 'pioneer', 'margaret', 'sanger', 'wasan', 'active', 'participant', 'ku', 'klux', 'klan']
#
#
# ['says', 'president', 'obama', 'national', 'labor', 'relations', 'board', 'sued', 'boeing', 'decision', 'open', 'plant', 'south', 'carolina']
#
#
# ['says', 'ron', 'johnson', 'led', 'fight', 'let', 'polluters', 'release', 'unlimited', 'amounts', 'carbon', 'pollution', 'took', 'nearly', 'polluters']
#
#
# ['orrin', 'hatch', 'health', 'care', 'bill', 'individual', 'mandate']
#
#
# ['more', 'graduate', 'students', 'arent']
#
#
# ['lloyd', 'doggett', 'liberal', 'man', 'united', 'states', 'congress']
#
#
# ['its', 'entirely', 'possible', 'democratic', 'nominee', 'hillary', 'clinton', 'earned', 'money', 'giving', 'single', 'speech', 'wall', 'street', 'i', 'made', 'six', 'years', 'i', 'back', 'in', 'fact', 'quite', 'likely']
#
#
# ['says', 'mitt', 'romney', 'assault', 'weapons', 'ban']
#
#
# ['says', 'state', 'senate', 'president', 'stephen', 'sweeney', 'gave', 'us', 'nations', 'highest', 'income', 'tax', 'rates', 'driving', 'jobs']
#
#
# ['delaware', 'democratic', 'senate', 'candidate', 'chris', 'coons', 'thought', 'call', 'taxed']
#
#
# ['when', 'tim', 'kaine', 'governor', 'spending', 'soared', 'blowing', 'holes', 'budget', 'every', 'year']
#
#
# ['president', 'obama', 'lowest', 'public', 'approval', 'ratings', 'president', 'modern', 'times']
#
#
# ['neville', 'chamberlain', 'told', 'british', 'people', 'accept', 'nazis', 'yes', 'dominate', 'continent', 'europe', 'problem', 'lets', 'appease', 'why', 'because', 'cant', 'done', 'we', 'possibly', 'stand']
#
#
# ['on', 'income', 'cap', 'recipients', 'popular', 'hope', 'scholarship']
#
#
# ['wisconsin', 'dead', 'last', 'midwest', 'job', 'creation']
#
#
# ['on', 'running', 'civil', 'polite', 'campaign']
#
#
# ['says', 'president', 'barack', 'obama', 'taken', 'days', 'vacation', 'since', 'sworn', 'compared', 'president', 'george', 'bush', 'point', 'presidency']
#
#
# ['the', 'federal', 'government', 'reviewed', 'verified', 'administrations', 'numbers', 'showing', 'wisconsin', 'added', 'jobs']
#
#
# ['tom', 'suozzi', 'raised', 'taxes', 'hundreds', 'millions', 'dollars', 'nassau', 'county', 'executive']
#
#
# ['john', 'holdren', 'director', 'white', 'house', 'office', 'science', 'technology', 'policy', 'proposed', 'forcing', 'abortions', 'putting', 'sterilants', 'drinking', 'water', 'control', 'population']
#
#
# ['mitt', 'romney', 'drove', 'canada', 'family', 'dog', 'seamus', 'strapped', 'roof', 'car']
#
#
# ['many', 'founding', 'fathers', 'actively', 'involved', 'cockfighting']
#
#
# ['says', 'state', 'sheila', 'harsdorf', 'wants', 'eliminate', 'medicare', 'know']
#
#
# ['the', 'majority', 'people', 'travelling', 'destination', 'resorts', 'going', 'primary', 'purpose', 'gambling']
#
#
# ['says', 'bill', 'nelson', 'voted', 'percent', 'time', 'barack', 'obama']
#
#
# ['i', 'i', 'i', 'say', 'i', 'say', 'climate', 'change', 'hoax', 'perpetrated', 'chinese']
#
#
# ['in', 'florida', 'waiting', 'list', 'child', 'care', 'waiting', 'lists', 'community', 'care', 'elderly']
#
#
# ['says', 'nfl', 'commissioner', 'roger', 'goodell', 'interviewed', 'domestic', 'abuse', 'victim', 'janay', 'rice', 'ray', 'rice', 'present', 'every', 'domestic', 'violence', 'agency', 'every', 'law', 'enforcement', 'agency', 'thats']
#
#
# ['i', 'tell', 'enhanced', 'interrogation', 'techniques', 'since', 'banned', 'administration', 'specifically', 'waterboarding', 'work']
#
#
# ['virginia', 'made', 'progress', 'jobs', 'since', 'bob', 'mcdonnell', 'took', 'office']
#
#
# ['the', 'iraq', 'study', 'group', 'reported', 'saddam', 'hussein', 'designs', 'reviving', 'nuclear', 'program']
#
#
# ['the', 'registry', 'around', 'long', 'time', 'research', 'thats', 'says', 'positive', 'impact', 'public', 'safety']
#
#
# ['ronald', 'reagan', 'raised', 'national', 'debt', 'times']
#
#
# ['on', 'whether', 'global', 'warming']
#
#
# ['the', 'number', 'inmates', 'since', 'death', 'row', 'dying', 'natural', 'causes', 'surpassed', 'number', 'inmates', 'executed']
#
#
# ['quite', 'frankly', 'bush', 'years', 'spending', 'multiplied', 'obama', 'years', 'mess']
#
#
# ['republicans', 'proposed', 'dozens', 'health', 'care', 'solutions', 'designed', 'help', 'control', 'costs', 'improve', 'quality']
#
#
# ['when', 'union', 'says', 'i', 'want', 'eliminate', 'tenure', 'thats', 'true']
#
#
# ['says', 'hillary', 'clinton', 'donated', 'every', 'cent', 'shes', 'ever', 'earned', 'speaking', 'fees', 'charity']
#
#
# ['charlottes', 'ordinance', 'would', 'opened', 'bathrooms', 'sexes', 'times', 'hadnt', 'overturned']
#
#
# ['eighty', 'percent', 'american', 'people', 'support', 'approach', 'federal', 'budget', 'problems', 'includes', 'revenues', 'includes', 'cuts']
#
#
# ['social', 'security', 'nothing', 'federal', 'deficit']
#
#
# ['about', 'percent', 'gun', 'sellers', 'responsible', 'half', 'guns', 'used', 'crimes']
#
#
# ['on', 'pay', 'fired', 'milwaukee', 'police', 'officers']
#
#
# ['texas', 'state', 'gone', 'longest', 'without', 'electing', 'democrat', 'statewide']
#
#
# ['says', 'cnn', 'reported', 'ben', 'carson', 'taking', 'break', 'campaigning', 'cruz', 'campaign', 'forwarded', 'news', 'volunteers']
#
#
# ['today', 'raised', 'poor', 'youre', 'likely', 'stay', 'poor', 'years', 'ago']
#
#
# ['says', 'president', 'barack', 'obama', 'told', 'room', 'students', 'children', 'every', 'time', 'i', 'clap', 'hands', 'together', 'child', 'america', 'dies', 'gun', 'violence', 'child', 'told', 'could', 'solve', 'problem', 'clapping']
#
#
# ['the', 'united', 'states', 'longest', 'surviving', 'constitution']
#
#
# ['says', 'in', 'oregon', 'percent', 'pregnancies', 'unintended']
#
#
# ['austin', 'school', 'district', 'teachers', 'lowest', 'paid', 'urban', 'texas', 'district', 'lowest', 'paid', 'surrounding', 'school', 'district']
#
#
# ['says', 'clackamas', 'county', 'urban', 'renewal', 'debt', 'oregon', 'counties', 'combined']
#
#
# ['nasa', 'scientists', 'fudged', 'numbers', 'make', 'hottest', 'year', 'overstate', 'extent', 'global', 'warming']
#
#
# ['the', 'university', 'wisconsin', 'system', 'larger', 'business', 'state', 'wisconsin']
#
#
# ['there', 'record', 'congresswoman', 'betty', 'sutton', 'ever', 'holding', 'single', 'town', 'hall', 'meeting', 'open', 'general', 'public']
#
#
# ['mark', 'herring', 'voted', 'allow', 'sex', 'offenders', 'including', 'rapists', 'serve', 'shorter', 'sentences']
#
#
# ['iraq', 'oilfields', 'world', 'behind', 'saudi', 'arabia']
#
#
# ['says', 'states', 'mandated', 'tests', 'come', 'english', 'company']
#
#
# ['says', 'got', 'twice', 'much', 'money', 'sale', 'county', 'grounds', 'land', 'milwaukee', 'county', 'executive', 'scott', 'walker', 'willing', 'accept']
#
#
# ['we', 'spend', 'tax', 'loopholes', 'annually', 'trillion', 'thats', 'spend', 'defense', 'budget', 'year', 'medicare', 'medicaid', 'year']
#
#
# ['on', 'bush', 'tax', 'cuts']
#
#
# ['over', 'half', 'black', 'workers', 'country', 'earn', 'less', 'hour']
#
#
# ['insured', 'floridians', 'pay', 'every', 'hospital', 'stay', 'cover', 'cost', 'uninsured']
#
#
# ['sixteen', 'million', 'jobs', 'created', 'ronald', 'reagans', 'presidency']
#
#
# ['this', 'would', 'largest', 'casino', 'united', 'states']
#
#
# ['barack', 'obama', 'health', 'care', 'plan', 'cost', 'taxpayers', 'cover', 'new', 'person']
#
#
# ['barack', 'obama', 'percent', 'votes', 'solely', 'along', 'party', 'line']
#
#
# ['president', 'obama', 'nancy', 'pelosi', 'said', 'obamacare', 'would', 'save', 'money', 'factored', 'years', 'worth', 'tax', 'revenue', 'six', 'half', 'years', 'worth', 'expenses']
#
#
# ['john', 'mccain', 'led', 'nonproliferation', 'issues', 'chance', 'senate']
#
#
# ['says', 'american', 'polling', 'shows', 'russian', 'president', 'vladimir', 'putin', 'percent', 'approval', 'rating']
#
#
# ['pasco', 'county', 'schools', 'graduation', 'rates', 'substantially', 'higher', 'state', 'average', 'dropout', 'rates', 'state', 'average']
#
#
# ['percent', 'states', 'united', 'states', 'electrocution', 'abolished']
#
#
# ['says', 'year', 'american', 'women', 'become', 'pregnant', 'rape', 'incest']
#
#
# ['bill', 'nelson', 'leased', 'land', 'owned', 'six', 'cows', 'taking', 'advantage', 'agricultural', 'tax', 'loophole', 'dodge', 'taxes', 'last', 'year']
#
#
# ['in', 'rural', 'virginia', 'warner', 'ran', 'points', 'ahead', 'traditional', 'democrat', 'ahead', 'senator', 'kaine', 'ahead', 'governor', 'mcauliffe']
#
#
# ['i', 'tell', 'certainty', 'capandtrade', 'would', 'devastating', 'impact', 'economy']
#
#
# ['today', 'many', 'florida', 'teachers', 'risk', 'pay', 'impacted', 'performance', 'children', 'even', 'classrooms', 'subject', 'areas']
#
#
# ['mitt', 'romney', 'left', 'massachusetts', 'billion', 'debt']
#
#
# ['says', 'barack', 'obama', 'promised', 'would', 'cut', 'deficit', 'half', 'didnt']
#
#
# ['old', 'city', 'philadelphiaused', 'dozen', 'clubs', 'thats', 'known', 'two']
#
#
# ['says', 'denmarks', 'suicide', 'rate', 'twice', 'high', 'united', 'states', 'past', 'five', 'decades']
#
#
# ['china', 'total', 'control', 'north', 'korea']
#
#
# ['the', 'fact', 'clinton', 'foundation', 'got', 'percent', 'overhead', 'percent', 'money', 'actually', 'getting', 'places']
#
#
# ['the', 'constitution', 'owes', 'notion', 'democracy', 'iroquois', 'tribes']
#
#
# ['since', 'first', 'year', 'businesses', 'last', 'count', 'moved', 'california', 'texas']
#
#
# ['barack', 'obama', 'provided', 'guns', 'mexican', 'drug', 'cartels']
#
#
# ['says', 'chris', 'koster', 'fell', 'silentas', 'attorney', 'general', 'pursuing', 'case', 'free', 'classified', 'service', 'accused', 'promoting', 'prostitution', 'accepting', 'campaign', 'contributions', 'people', 'affiliated', 'service']
#
#
# ['health', 'care', 'premiums', 'consumers', 'doubled', 'since']
#
#
# ['says', 'less', 'half', 'states', 'legal', 'protections', 'basis', 'sexual', 'orientation', 'gender', 'identity', 'despite', 'fact', 'lgbt', 'americans', 'report', 'employment', 'discrimination', 'unemployment', 'much', 'higher', 'rates', 'average']
#
#
# ['gov', 'romney', 'republican', 'governors', 'supported', 'policies', 'would', 'eliminated', 'time', 'limits', 'welfare', 'reform', 'law', 'allowed', 'people', 'stay', 'welfare', 'forever']
#
#
# ['under', 'gov', 'lee', 'fisher', 'ohio', 'country', 'terms', 'getting', 'money', 'actually', 'worker', 'retraining']
#
#
# ['im', 'well', 'aware', 'medical', 'marijuana', 'recognized', 'medical', 'viable', 'treatment', 'sort', 'pancreas', 'pain', 'condition']
#
#
# ['says', 'rick', 'perry', 'recently', 'said', 'wanted', 'another', 'texas', 'business', 'tax']
#
#
# ['by', 'margin', 'rhode', 'islanders', 'want', 'ban', 'assault', 'weapons', 'small', 'percentage', 'gun', 'owners', 'state', 'less', 'percent']
#
#
# ['right', 'employer', 'chance', 'getting', 'hit', 'lightning', 'prosecuted', 'hiring', 'undocumented', 'worker', 'that', 'change']
#
#
# ['wisconsin', 'dropped', 'second', 'country', 'among', 'states', 'half', 'students', 'took', 'act', 'exam']
#
#
# ['says', 'mostly', 'minority', 'texas', 'students', 'enrolled', 'failing', 'schools']
#
#
# ['says', 'at', 'age', 'need', 'eligible', 'cancer', 'treatment', 'affordable', 'care', 'act']
#
#
# ['says', 'obama', 'administration', 'policy', 'prohibits', 'people', 'work', 'youth', 'promoting', 'marriage', 'way', 'avoid', 'poverty']
#
#
# ['secret', 'documents', 'reveal', 'iran', 'could', 'obtain', 'nuclear', 'weapon', 'far', 'sooner', 'told', 'and', 'tammy', 'duckworth', 'voted', 'yes', 'iran', 'nuclear', 'deal']
#
#
# ['if', 'look', 'results', 'obamacare', 'see', 'emergency', 'room', 'visits', 'percent']
#
#
# ['loranne', 'ausley', 'voted', 'six', 'times', 'tax', 'savings']
#
#
# ['four', 'state', 'assembly', 'democrats', 'scored', 'death', 'blow', 'northeast', 'wisconsins', 'economy', 'killing', 'hundreds', 'jobs', 'potential', 'bass', 'pro', 'shops', 'near', 'green', 'bay']
#
#
# ['the', 'president', 'campaigned', 'type', 'legislation']
#
#
# ['one', 'every', 'three', 'women', 'abortion', 'lifetime']
#
#
# ['barack', 'obama', 'left', 'announced', 'socialist', 'united', 'states', 'senate']
#
#
# ['what', 'president', 'worst', 'record', 'female', 'labor', 'force', 'participation', 'barack', 'obama']
#
#
# ['two', 'million', 'latinos', 'poverty', 'today', 'president', 'obamatook', 'oath', 'office', 'less', 'eight', 'years', 'ago']
#
#
# ['the', 'social', 'security', 'trust', 'fund', 'already', 'facing', 'imminent', 'bankruptcy']
#
#
# ['seven', 'hundred', 'thousand', 'thats', 'many', 'california', 'jobs', 'lost', 'thanks', 'politicians', 'raising', 'minimum', 'florida', 'adding', 'one', 'million', 'jobs', 'losing']
#
#
# ['america', 'no', 'wind', 'power']
#
#
# ['the', 'percentage', 'black', 'children', 'born', 'without', 'father', 'home', 'risen', 'percent', 'percent', 'today', 'due', 'changes', 'president', 'lyndon', 'johnsons', 'great', 'society']
#
#
# ['i', 'said', 'big', 'bank', 'bailouts']
#
#
# ['people', 'constitutional', 'right', 'semiautomatic', 'rifles']
#
#
# ['this', 'budget', 'also', 'reflects', 'smallest', 'state', 'government', 'workforce', 'per', 'residents', 'florida', 'century']
#
#
# ['the', 'film', 'tv', 'industry', 'supports', 'direct', 'jobs', 'pays', 'local', 'workers', 'billion', 'wages', 'georgia']
#
#
# ['property', 'taxes', 'increased', 'percent', 'four', 'years', 'chris', 'christie']
#
#
# ['when', 'comes', 'income', 'taxes', 'wisconsin', 'one', 'best', 'places', 'country', 'poor', 'top', 'worst', 'earners']
#
#
# ['acorn', 'could', 'get', 'billion', 'tax', 'dollars', 'despite', 'investigation', 'voter', 'registration', 'fraud', 'dozen', 'states']
#
#
# ['says', 'congressman', 'jon', 'runyan', 'want', 'cut', 'taxes', 'middle', 'class', 'millionaires']
#
#
# ['on', 'half', 'pay', 'pledge']
#
#
# ['over', 'years', 'extending', 'tax', 'cuts', 'wealthy', 'would', 'add', 'less', 'deficit', 'obama', 'added', 'stimulus', 'one', 'year']
#
#
# ['the', 'collective', 'net', 'worth', 'americans', 'taken', 'trillion', 'hit', 'mainly', 'due', 'plummeting', 'home', 'values']
#
#
# ['gov', 'rick', 'scott', 'backed', 'federal', 'shutdown']
#
#
# ['the', 'average', 'georgia', 'family', 'makes', 'less', 'average', 'family', 'years', 'ago', 'inflation', 'factored']
#
#
# ['as', 'weve', 'seen', 'federal', 'support', 'states', 'diminish', 'youve', 'seen', 'biggest', 'job', 'losses', 'public', 'sector', 'teachers', 'police', 'officers', 'firefighters', 'losing', 'jobs']
#
#
# ['says', 'new', 'start', 'passed', 'clinton', 'secretary', 'state', 'treaty', 'cutting', 'russias', 'nuclear', 'arms']
#
#
# ['says', 'free', 'public', 'university', 'tuition', 'program', 'paid', 'tax', 'wall', 'streets', 'speculation']
#
#
# ['ohio', 'ranks', 'country', 'putting', 'dollars', 'classroom']
#
#
# ['under', 'wisconsin', 'bill', 'minor', 'offenses', 'violating', 'pet', 'leash', 'laws', 'seat', 'belt', 'laws', 'parking', 'infractions', 'would', 'arrestable', 'offenses']
#
#
# ['says', 'texas', 'cut', 'billion', 'entire', 'budget', 'yet', 'put', 'billion', 'public', 'education', 'we', 'put', 'million', 'health', 'human', 'services']
#
#
# ['under', 'hillary', 'clintons', 'plan', 'illegal', 'immigrants', 'convicted', 'committing', 'crimes', 'get', 'stay']
#
#
# ['the', 'obama', 'administration', 'leaked', 'information', 'deliberately', 'otherwise', 'led', 'identification', 'pakistani', 'doctor', 'helped', 'us', 'achieving', 'goals', 'killing', 'bin', 'laden']
#
#
# ['over', 'last', 'several', 'months', 'review', 'board', 'headed', 'two', 'distinguished', 'americans', 'mike', 'mullen', 'tom', 'pickering', 'investigated', 'every', 'element', 'benghazi', 'incident']
#
#
# ['says', 'governor', 'came', 'office', 'billion', 'dollar', 'i', 'call', 'mismanagement', 'deficit']
#
#
# ['georgia', 'states', 'weak', 'gun', 'laws', 'crime']
#
#
# ['says', 'president', 'barack', 'obama', 'spent', 'nearly', 'trillion', 'dollars', 'government', 'jobs']
#
#
# ['among', 'hispanics', 'support', 'immigration', 'reform', 'close', 'universal']
#
#
# ['says', 'ted', 'cruz', 'ad', 'got', 'never', 'bulldozed', 'its', 'false', 'advertising']
#
#
# ['wages', 'adjusted', 'inflation', 'havent', 'risen', 'since', 'turn', 'last', 'century']
#
#
# ['says', 'percent', 'people', 'caught', 'crossing', 'border', 'said', 'survey', 'coming', 'weve', 'promised', 'amnesty']
#
#
# ['there', 'would', 'tens', 'thousands', 'jobs', 'created', 'president', 'barack', 'obama', 'approved', 'keystone', 'xl', 'pipeline']
#
#
# ['weve', 'brought', 'trade', 'cases', 'china', 'nearly', 'twice', 'rate', 'last', 'administration']
#
#
# ['when', 'started', 'health', 'care', 'debate', 'year', 'ago', 'percent', 'american', 'people', 'health', 'insurance', 'percent', 'percent', 'happy']
#
#
# ['since', 'john', 'kennedy', 'assassinated', 'americans', 'died', 'gunfire', 'within', 'country', 'american', 'servicemen', 'women', 'killed', 'wars']
#
#
# ['obama', 'said', 'would', 'unilaterally', 'renegotiate', 'north', 'american', 'free', 'trade', 'agreement']
#
#
# ['in', 'days', 'trayvon', 'dying', 'todays', 'verdict', 'murdered']
#
#
# ['says', 'if', 'compare', 'portland', 'metro', 'area', 'cdcs', 'statewide', 'cavity', 'rates', 'portland', 'metro', 'area', 'would', 'actually', 'rank', 'lowest', 'cavity', 'rate']
#
#
# ['he', 'received', 'a', 'ratings', 'every', 'conservative', 'organization', 'gives', 'ratings']
#
#
# ['it', 'costs', 'year', 'keep', 'child', 'school', 'costs', 'year', 'keep', 'someone', 'prison']
#
#
# ['says', 'republican', 'charlie', 'dent', 'wants', 'kick', 'freedom', 'caucus', 'republican', 'conference', 'voting', 'conscience']
#
#
# ['he', 'offered', 'medical', 'care', 'injuries', 'would', 'give', 'military', 'information', 'return', 'john', 'mccain', 'said']
#
#
# ['wisconsin', 'corporations', 'dont', 'pay', 'state', 'income', 'taxes']
#
#
# ['there', 'literally', 'teachers', 'getting', 'pink', 'slips', 'sequestration']
#
#
# ['obamacare', 'kill', 'jobs', 'across', 'america']
#
#
# ['last', 'weeks', 'three', 'television', 'programs', 'weresunday', 'night', 'football', 'thursday', 'night', 'football', 'monday', 'night', 'football']
#
#
# ['on', 'federal', 'stimulus', 'money', 'expanding', 'rail', 'service']
#
#
# ['about', 'soldiers', 'prescription', 'three', 'weeks', 'pain', 'depression', 'anxiety', 'medication']
#
#
# ['georgia', 'loses', 'millions', 'dollars', 'revenue', 'people', 'go', 'state', 'buy', 'fireworks']
#
#
# ['if', 'i', 'fail', 'defund', 'obamacare', 'new', 'irs', 'agents', 'begin', 'prying', 'private', 'medical', 'records', 'eyeing', 'every', 'one', 'treatments', 'prescriptions', 'violations']
#
#
# ['john', 'mccain', 'says', 'okay', 'spends', 'next', 'thousand', 'years', 'iraq']
#
#
# ['says', 'illegal', 'immigrants', 'accounted', 'percent', 'federal', 'drug', 'possession', 'convictions', 'percent', 'percent', 'convictions', 'murder', 'kidnapping', 'plus', 'two', 'crimes']
#
#
# ['the', 'clinton', 'foundation', 'charity', 'president', 'secretary', 'clinton', 'daughter', 'take', 'salary', 'get', 'money', 'take', 'personal', 'benefit']
#
#
# ['says', 'bill', 'hb', 'would', 'prevent', 'use', 'taxpayer', 'dollars', 'abortions']
#
#
# ['the', 'average', 'atlanta', 'resident', 'spends', 'extra', 'year', 'additional', 'gasoline', 'wasted', 'time']
#
#
# ['federal', 'health', 'care', 'reforms', 'amounted', 'government', 'takeover', 'health', 'care']
#
#
# ['barack', 'obama', 'hillary', 'clinton', 'changed', 'positions', 'iraq', 'war', 'withdrawal', 'follow', 'chris', 'dodd']
#
#
# ['saturday', 'night', 'live', 'executive', 'producer', 'lorne', 'michaels', 'could', 'put', 'jail', 'amendment', 'making', 'fun', 'politician']
#
#
# ['when', 'worked', 'att', 'responsible', 'large', 'parts', 'billion', 'organization']
#
#
# ['ohioans', 'lost', 'manufacturing', 'jobs', 'month', 'september']
#
#
# ['mitch', 'mcconnell', 'voted', 'harry', 'reid', 'infringe', 'gun', 'rights']
#
#
# ['says', 'ron', 'johnson', 'gave', 'million', 'sweetheart', 'corporate', 'payout']
#
#
# ['of', 'roughly', 'percent', 'americans', 'dont', 'health', 'insurance', 'half', 'made', 'year']
#
#
# ['the', 'united', 'states', 'immediately', 'tap', 'domestic', 'energy', 'resource', 'trillion', 'barrels', 'oil', 'six', 'times', 'saudi', 'arabia']
#
#
# ['says', 'house', 'democrats', 'voted', 'use', 'tax', 'dollars', 'abortions', 'voting', 'bill', 'defunding', 'planned', 'parenthood']
#
#
# ['we', 'need', 'senator', 'shows', 'work', 'sherrod', 'brown', 'missed', 'official', 'votes']
#
#
# ['it', 'already', 'law', 'requirement', 'screen', 'refugees', 'religion']
#
#
# ['at', 'mere', 'request', 'putin', 'president', 'obama', 'withdrew', 'plans', 'missile', 'defense', 'program', 'based', 'poland', 'czech', 'republic']
#
#
# ['i', 'well', 'young', 'people', 'ohio', 'massachusetts', 'california']
#
#
# ['health', 'care', 'reform', 'would', 'bring', 'deficit', 'much', 'trillion', 'next', 'two', 'decades']
#
#
# ['mccain', 'opposed', 'stem', 'cell', 'research']
#
#
# ['austin', 'lobbyists', 'working', 'municipality', 'texas']
#
#
# ['the', 'epa', 'wants', 'hire', 'new', 'government', 'regulators', 'cost', 'taxpayer', 'billion']
#
#
# ['if', 'partnership', 'senate', 'wont', 'receive', 'committee', 'assignment', 'consideration', 'include', 'debate']
#
#
# ['on', 'whether', 'government', 'bail', 'insurance', 'giant', 'aig']
#
#
# ['the', 'cleveland', 'police', 'issued', 'stand', 'order', 'officers']
#
#
# ['the', 'keystone', 'pipeline', 'creates', 'permanent', 'jobs', 'construction', 'according', 'government', 'report']
#
#
# ['we', 'already', 'pay', 'highest', 'electricity', 'prices', 'country', 'new', 'england']
#
#
# ['we', 'going', 'troops', 'afghanistan', 'russians']
#
#
# ['victory', 'republicans', 'vote', 'endorse', 'mark', 'neumann', 'first', 'ballot', 'gop', 'convention']
#
#
# ['florida', 'investing', 'record', 'amounts', 'funding', 'prevention']
#
#
# ['there', 'four', 'senators', 'senior', 'still', 'older']
#
#
# ['all', 'four', 'mount', 'rushmore', 'independents', 'one', 'critical', 'point', 'career']
#
#
# ['we', 'didnt', 'go', 'asking', 'people', 'join', 'stand', 'ground', 'task', 'force']
#
#
# ['rhode', 'islands', 'exports', 'increased', 'percent', 'last', 'two', 'years']
#
#
# ['giant', 'companies', 'like', 'toyota', 'locate', 'state', 'passed', 'law']
#
#
# ['mitt', 'romney', 'boasts', 'proud', 'major', 'candidate', 'president', 'sign', 'tax', 'pledge', 'the', 'others']
#
#
# ['more', 'voter', 'registration', 'groups', 'ranging', 'across', 'entire', 'political', 'spectrum', 'filed', 'state', 'registering', 'voters', 'right']
#
#
# ['barack', 'obama', 'got', 'campaign', 'contributions', 'fannie', 'mae', 'freddie', 'mac', 'member', 'congress', 'except', 'democratic', 'chairmen', 'committee', 'oversees']
#
#
# ['i', 'brought', 'crime', 'anyone', 'country', 'maybe', 'history', 'country', 'i', 'mayor', 'new', 'york', 'city']
#
#
# ['a', 'planning', 'group', 'said', 'meet', 'anticipated', 'traffic', 'demands', 'interstate', 'austin', 'round', 'rock', 'need', 'dozen', 'additional', 'lanes', 'going', 'north', 'additional', 'southbound', 'lanes']
#
#
# ['foreign', 'chinese', 'prostitution', 'money', 'allegedly', 'behind', 'groups', 'funding', 'congressman', 'sean', 'duffys', 'republican', 'majority']
#
#
# ['the', 'united', 'states', 'developed', 'country', 'world', 'without', 'paid', 'maternity', 'leave']
#
#
# ['a', 'voucher', 'school', 'closed', 'days', 'year', 'collected', 'million', 'taxpayer', 'subsidies', 'since', 'first', 'opening']
#
#
# ['rhode', 'islands', 'unemployment', 'insurance', 'system', 'expensive', 'system', 'country']
#
#
# ['says', 'youtube', 'video', 'shows', 'thomas', 'dimassimo', 'man', 'rushed', 'trump', 'ohio', 'rally', 'dragging', 'american', 'flag', 'ground', 'like', 'piece', 'garbage']
#
#
# ['obama', 'worked', 'dick', 'lugar', 'republican', 'help', 'lock', 'loose', 'nuclear', 'weapons']
#
#
# ['the', 'united', 'states', 'spends', 'billion', 'free', 'cell', 'phones', 'million', 'moroccan', 'pottery', 'classes', 'pays', 'travel', 'expenses', 'watermelon', 'queen', 'alabama']
#
#
# ['the', 'united', 'states', 'historic', 'record', 'highs', 'individuals', 'apprehended', 'border', 'countries', 'terrorist', 'ties', 'pakistan', 'afghanistan', 'syria']
#
#
# ['the', 'transportation', 'package', 'passed', 'general', 'assembly', 'would', 'impose', 'largest', 'tax', 'increase', 'virginias', 'history']
#
#
# ['my', 'home', 'state', 'since', 'june', 'created', 'percent', 'new', 'jobs', 'america']
#
#
# ['onion', 'creeks', 'highest', 'flow', 'rate', 'recent', 'night', 'flooding', 'cubic', 'feet', 'per', 'second', 'nearly', 'double', 'average', 'flow', 'rate', 'niagara', 'falls']
#
#
# ['as', 'governor', 'florida', 'i', 'used', 'combination', 'strategies', 'help', 'reduce', 'heroin', 'use', 'among', 'youth', 'florida', 'approximately', 'percent']
#
#
# ['says', 'last', 'year', 'million', 'health', 'insurance', 'rebates', 'went', 'states', 'another', 'million', 'rebates', 'sent', 'summer', 'averaging', 'around', 'bucks']
#
#
# ['says', 'state', 'budget', 'provide', 'increase', 'state', 'funding', 'school', 'year']
#
#
# ['says', 'estate', 'tax', 'many', 'cases', 'forces', 'family', 'farmers', 'small', 'businesses', 'owners', 'sell', 'holdings']
#
#
# ['sayvideo', 'shows', 'massive', 'alligator', 'strolling', 'across', 'florida', 'golf', 'course']
#
#
# ['on', 'whether', 'people', 'keep', 'insurance', 'affordable', 'care', 'act']
#
#
# ['we', 'spending', 'billion', 'latin', 'america', 'terms', 'aid', 'assistance', 'fraction', 'spending', 'iraq', 'billion', 'spent']
#
#
# ['if', 'look', 'number', 'illegal', 'immigrants', 'coming', 'country', 'net', 'zero', 'its', 'way', 'almost', 'two', 'years']
#
#
# ['weve', 'introduced', 'bill', 'includes', 'billion', 'cuts', 'next', 'week']
#
#
# ['wisconsins', 'lawsuit', 'rules', 'states', 'system', 'one', 'promiscuous', 'america']
#
#
# ['says', 'joseph', 'stalin', 'said', 'want', 'bring', 'america', 'undermine', 'three', 'things', 'spiritual', 'life', 'patriotism', 'morality']
#
#
# ['from', 'pay', 'russians', 'million', 'astronaut', 'send', 'americans', 'space', 'station']
#
#
# ['the', 'gender', 'gap', 'support', 'unique', 'theres', 'huge', 'gap', 'republicans', 'presidential', 'gubernatorial', 'us', 'senate', 'elections', 'recent', 'years']
#
#
# ['bryce', 'reeves', 'chaired', 'group', 'bankrolled', 'new', 'york', 'billionaire', 'fired', 'hundreds', 'virginia', 'workers', 'sent', 'jobs', 'china']
#
#
# ['in', 'alabama', 'massachusetts', 'passed', 'legislation', 'allowing', 'legal', 'residents', 'vote', 'state', 'local', 'elections']
#
#
# ['across', 'country', 'half', 'attorney', 'seats', 'remain', 'without', 'prosecutor', 'chosen', 'obama']
#
#
# ['the', 'red', 'sox', 'waited', 'long', 'years', 'win', 'world', 'series']
#
#
# ['almost', 'every', 'state', 'offered', 'insurance', 'plan', 'health', 'exchange', 'cover', 'abortion']
#
#
# ['the', 'largest', 'tax', 'increase', 'ever', 'state', 'business', 'margins', 'tax', 'signed', 'governor']
#
#
# ['georgia', 'rate', 'childhood', 'obesity', 'united', 'states']
#
#
# ['says', 'tom', 'ganley', 'sued', 'times', 'fraud', 'discrimination', 'judge', 'called', 'tom', 'ganleys', 'business', 'practices', 'deceptive', 'unconscionable']
#
#
# ['a', 'recall', 'election', 'wisconsin', 'governor', 'would', 'cost', 'million', 'million', 'may', 'already', 'allocated', 'merit', 'raises', 'teachers', 'health', 'care', 'poor', 'school', 'books', 'kids']
#
#
# ['says', 'plan', 'property', 'tax', 'cut']
#
#
# ['we', 'giving', 'almost', 'billion', 'taxpayer', 'money', 'junk', 'food', 'fast', 'food', 'industries', 'every', 'year', 'make', 'childhood', 'obesity', 'epidemic', 'worse']
#
#
# ['not', 'one', 'american', 'flag', 'massive', 'stage', 'democratic', 'national', 'convention', 'people', 'started', 'small', 'one', 'pathetic']
#
#
# ['a', 'bill', 'earl', 'blumenauer', 'would', 'mandate', 'gps', 'tracking', 'devices', 'vehicles']
#
#
# ['as', 'prosecutor', 'wisconsin', 'supreme', 'court', 'justice', 'david', 'prosser', 'investigate', 'file', 'charges', 'case', 'involving', 'pedophile', 'priest', 'participated']
#
#
# ['there', 'precedent', 'nominating', 'someone', 'supreme', 'court', 'middle', 'presidential', 'election']
#
#
# ['health', 'insurance', 'medical', 'costs', 'going', 'obamacare']
#
#
# ['the', 'war', 'drugs', 'led', 'percent', 'increase', 'incarceration', 'country', 'disproportionately', 'affecting', 'poor', 'disproportionately', 'affecting', 'minorities']
#
#
# ['says', 'texas', 'gop', 'platform', 'calls', 'end', 'teaching', 'critical', 'thinking', 'public', 'schools']
#
#
# ['four', 'homicides', 'committed', 'gun', 'city']
#
#
# ['a', 'picture', 'shows', 'former', 'president', 'bill', 'clinton', 'naked', 'another', 'woman']
#
#
# ['there', 'disagreement', 'need', 'action', 'government', 'recovery', 'plan', 'help', 'economy']
#
#
# ['if', 'want', 'individual', 'mandate', 'tick', 'box', 'says', 'hardshipand', 'youre']
#
#
# ['many', 'nevadans', 'relied', 'uber', 'work', 'accepting', 'taxi', 'companies', 'catherine', 'cortez', 'masto', 'went', 'uber', 'driving', 'town']
#
#
# ['says', 'probably', 'costs', 'run', 'seat', 'pedernales', 'electric', 'cooperative', 'board', 'directors']
#
#
# ['last', 'month', 'states', 'saw', 'increase', 'unemployment', 'rate']
#
#
# ['wind', 'power', 'undependable', 'form', 'renewable', 'energy']
#
#
# ['charlie', 'crist', 'allowed', 'college', 'tuition', 'increase', 'percent', 'every', 'year']
#
#
# ['the', 'house', 'never', 'failed', 'pass', 'budget', 'modern', 'era']
#
#
# ['renacci', 'registered', 'foreign', 'trade', 'lobbyist', 'united', 'states', 'government']
#
#
# ['tommy', 'thompson', 'created', 'first', 'school', 'choice', 'program', 'nation', 'giving', 'thousands', 'milwaukee', 'students', 'choice', 'go', 'school', 'matter', 'live', 'much', 'money', 'parents', 'make']
#
#
# ['says', 'main', 'central', 'texas', 'food', 'bank', 'delivering', 'percent', 'food', 'poor', 'three', 'years', 'ago']
#
#
# ['mccain', 'still', 'thinks', 'okay', 'women', 'earn', 'equal', 'pay', 'equal', 'work']
#
#
# ['the', 'baucus', 'bill', 'contains', 'provisions', 'would', 'send', 'massive', 'federal', 'subsidies', 'directly', 'private', 'insurance', 'plans', 'cooperatives', 'pay', 'elective', 'abortion']
#
#
# ['gene', 'green', 'nras', 'favorite', 'democrat', 'congress', 'its', 'wonder', 'congressman', 'lifetime', 'a', 'rating', 'nra']
#
#
# ['obama', 'health', 'care', 'people']
#
#
# ['the', 'cbo', 'says', 'raise', 'minimum', 'wage', 'hour', 'half', 'million', 'people', 'would', 'lose', 'jobs']
#
#
# ['state', 'lawmakers', 'spending', 'taxpayer', 'money', 'parking', 'billionaire', 'arthur', 'blank', 'could', 'build', 'paying', 'state', 'employees', 'little', 'food', 'stamps']
#
#
# ['state', 'governments', 'little', 'ability', 'stimulate', 'job', 'growth', 'short', 'run']
#
#
# ['he', 'obama', 'chairs', 'subcommittee', 'europe', 'he', 'held', 'one', 'substantive', 'hearing', 'oversight']
#
#
# ['says', 'federal', 'income', 'tax', 'rate', 'percent']
#
#
# ['sarah', 'palin', 'already', 'executive', 'experience', 'barack', 'obama', 'joe', 'biden', 'combined']
#
#
# ['texas', 'highest', 'share', 'workers', 'nation']
#
#
# ['two', 'months', 'ago', 'donald', 'trump', 'said', 'isis', 'fight']
#
#
# ['says', 'average', 'democratic', 'congressional', 'districts', 'received', 'percent', 'stimulus', 'funds', 'republican', 'districts']
#
#
# ['you', 'supported', 'john', 'mccain', 'military', 'strategies', 'pretty', 'adamantly', 'race']
#
#
# ['says', 'critics', 'say', 'cut', 'medicaid', 'wrong', 'budget', 'added', 'billion', 'program']
#
#
# ['says', 'work', 'raise', 'federal', 'minimum', 'wage', 'back', 'highest', 'level', 'ever', 'hour', 'todays', 'dollars']
#
#
# ['families', 'snap', 'food', 'stamps', 'live', 'week']
#
#
# ['the', 'medford', 'water', 'commission', 'fined', 'dumping', 'plain', 'drinking', 'water', 'stream']
#
#
# ['nothing', 'constitution', 'explicitly', 'guarantees', 'right', 'vote']
#
#
# ['sherrod', 'brown', 'special', 'interest', 'allies', 'washington', 'plotting', 'spend', 'million', 'defeat', 'josh', 'mandel']
#
#
# ['on', 'new', 'dollar', 'coins', 'god', 'we', 'trust', 'gone']
#
#
# ['says', 'gov', 'scott', 'walkers', 'proposed', 'state', 'budget', 'contained', 'pages', 'errors', 'unusually', 'high', 'number', 'millions', 'dollars', 'worth', 'mistakes', 'corrected', 'document']
#
#
# ['takes', 'credit', 'substantially', 'reducing', 'size', 'state', 'workforce']
#
#
# ['if', 'look', 'polls', 'race', 'fourth', 'july', 'mitt', 'romney', 'president']
#
#
# ['in', 'last', 'years', 'georgias', 'middle', 'class', 'income', 'dropped']
#
#
# ['rooting', 'red', 'sox', 'like', 'rooting', 'drug', 'companies']
#
#
# ['says', 'rick', 'perrys', 'pay', 'play', 'politics', 'led', 'send', 'million', 'offshore', 'call', 'center', 'bermuda', 'driving', 'enrollment', 'childrens', 'health', 'insurance']
#
#
# ['on', 'allowing', 'vote', 'universal', 'gun', 'background', 'checks', 'senate']
#
#
# ['president', 'barack', 'obama', 'nancy', 'pelosi', 'harry', 'reid', 'support', 'rick', 'perrys', 'decision', 'give', 'tuition', 'illegal', 'immigrants']
#
#
# ['obama', 'czars', 'romanovs']
#
#
# ['gov', 'mcdonnells', 'proposed', 'budget', 'cutting', 'public', 'education']
#
#
# ['a', 'bank', 'surveillance', 'camera', 'capturing', 'criminals', 'face', 'identifiable', 'traits', 'would', 'certainly', 'discourage', 'robbery', 'attempts', 'serve', 'deterrent', 'robbers']
#
#
# ['medicare', 'costs', 'slowed', 'dramatically', 'in', 'fact', 'first', 'two', 'months', 'fiscal', 'year', 'medicare', 'costs', 'even', 'nominal', 'terms', 'relative', 'previous', 'year']
#
#
# ['says', 'donald', 'trump', 'mike', 'pence', 'want', 'gamble', 'retirement', 'benefits', 'stock', 'market']
#
#
# ['connie', 'mack', 'voted', 'raise', 'pay', 'several', 'times']
#
#
# ['no', 'poll', 'done', 'year', 'shows', 'less', 'majority', 'reinstate', 'federal', 'ban', 'assault', 'weapons']
#
#
# ['i', 'spent', 'virtually', 'every', 'weekend', 'since', 'memorial', 'day', 'panhandle']
#
#
# ['in', 'election', 'votes', 'cast', 'registered', 'voters', 'lucie', 'county', 'palm', 'beach', 'county', 'percent', 'turnout']
#
#
# ['im', 'conspiracy', 'theorist', 'i', 'never', 'allow', 'conspiracy', 'theorists', 'program']
#
#
# ['says', 'romney', 'called', 'russia', 'no', 'enemy']
#
#
# ['theres', 'conclusive', 'specific', 'report', 'say', 'russia', 'trying', 'muddy', 'election']
#
#
# ['says', 'christopher', 'little', 'history', 'working', 'environmental', 'protection', 'defending', 'worst', 'types', 'corporate', 'polluters']
#
#
# ['john', 'kasich', 'says', 'despite', 'visits', 'president', 'somewhere', 'million', 'million', 'spent', 'paid', 'volunteers', 'calling', 'every', 'name', 'book', 'former', 'presidents', 'first', 'ladies']
#
#
# ['opponents', 'section', 'voting', 'rights', 'act', 'complain', 'state', 'expense', 'yet', 'cost', 'paper', 'postage', 'manpower', 'required', 'send', 'copies', 'legislation', 'federal', 'government', 'review']
#
#
# ['says', 'nick', 'kahl', 'made', 'harder', 'many', 'families', 'cover', 'basic', 'health', 'care', 'expenses']
#
#
# ['in', 'california', 'windmills', 'killing', 'hundreds', 'hundreds', 'eagles']
#
#
# ['there', 'nothing', 'current', 'state', 'public', 'records', 'law', 'prohibits', 'sensitive', 'confidential', 'business', 'information', 'confidential']
#
#
# ['we', 'even', 'federal', 'income', 'tax', 'country']
#
#
# ['the', 'white', 'house', 'swing', 'states', 'i', 'winning', 'swing', 'states']
#
#
# ['says', 'opponent', 'gwen', 'moore', 'wisconsins', 'absent', 'member', 'congress', 'missing', 'nearly', 'percent', 'house', 'votes', 'second', 'quarter']
#
#
# ['says', 'gov', 'scott', 'walker', 'dropped', 'kicked', 'college', 'short', 'degree', 'long', 'kicked', 'student', 'elections', 'marquette', 'university']
#
#
# ['eliminating', 'affirmative', 'action', 'admissions', 'florida', 'led', 'african', 'american', 'hispanic', 'kids', 'attending', 'university', 'system']
#
#
# ['when', 'comes', 'transportation', 'funds', 'georgians', 'spend', 'taxes', 'red', 'tape', 'get', 'back', 'federal', 'government']
#
#
# ['federal', 'stimulus', 'money', 'went', 'georgia', 'tech', 'project', 'apparently', 'involve', 'professor', 'jamming', 'musicians', 'hopefully', 'also', 'create', 'satisfying', 'works', 'art']
#
#
# ['the', 'doesnt', 'make', 'television', 'sets', 'anymore']
#
#
# ['when', 'republicans', 'including', 'boehner', 'charge', 'number', 'earmarks', 'pet', 'projects', 'went']
#
#
# ['wisconsins', 'projected', 'state', 'budget', 'shortfall', 'low', 'billion']
#
#
# ['heroin', 'pours', 'across', 'southern', 'borders']
#
#
# ['before', 'republican', 'wave', 'democrats', 'advantage', 'generic', 'ballot', 'congress', 'even', 'gingrich', 'revolution', 'democrats', 'advantage']
#
#
# ...
#
#
# ['scott', 'walker', 'gpa', 'asked', 'leave', 'marquette', 'university', 'cheating']
#
#
# ['says', 'company', 'got', 'tax', 'breaks', 'state', 'later', 'laid', 'ohioans', 'even', 'ceo', 'cut', 'check', 'kasichs', 'super', 'pac']
#
#
# ['ohio', 'director', 'job', 'creation', 'mark', 'kvamme', 'clawed', 'back', 'companies', 'made', 'promises', 'didnt', 'keep']
#
#
# ['there', 'clinical', 'evidence', 'vaccinating', 'healthcare', 'workers', 'protects', 'patients']
#
#
# ['on', 'tuition', 'unauthorized', 'immigrants']
#
#
# ['i', 'made', 'bunch', 'promises', 'campaign', 'weve', 'got', 'percent', 'done', 'three', 'years']
#
#
# ['on', 'day', 'new', 'hampshire', 'primary', 'top', 'people', 'ronald', 'reagans', 'staff', 'quit']
#
#
# ['some', 'wealthiest', 'americans']
#
#
# ['theres', 'people', 'working', 'health', 'care', 'today', 'new', 'hampshire', 'passed', 'budget']
#
#
# ['president', 'barack', 'obamas', 'health', 'care', 'reform', 'slashed', 'billion', 'medicare']
#
#
# ['the', 'ranks', 'world', 'health', 'care']
#
#
# ['a', 'high', 'school', 'dropout', 'makes', 'average', 'year', 'high', 'school', 'graduate', 'makes', 'year', 'college', 'graduate', 'makes', 'year']
#
#
# ['theres', 'almost', 'million', 'texans', 'unemployed', 'thats', 'record', 'number', 'state']
#
#
# ['nearly', 'percent', 'federal', 'spending', 'go', 'towards', 'social', 'security', 'medicare', 'medicaid', 'fiscal', 'year']
#
#
# ['in', 'ohio', 'year', 'estimated', 'children', 'become', 'victims', 'human', 'trafficking', 'risk']
#
#
# ['claims', 'obama', 'said', 'for', 'oppose', 'policies', 'shut', 'go', 'away']
#
#
# ['says', 'yet', 'salem', 'traditionally', 'waited', 'money', 'almost', 'gone', 'pay', 'important', 'things', 'states', 'budget']
#
#
# ['percent', 'land', 'state', 'right', 'either', 'federally', 'state', 'county', 'owned', 'conservation', 'purposes']
#
#
# ['the', 'race', 'tighten', 'happens', 'end', 'campaigns', 'they', 'always']
#
#
# ['even', 'obamacare', 'fully', 'implemented', 'still', 'tens', 'millions', 'people', 'covered']
#
#
# ['the', 'obama', 'administrations', 'regulatory', 'assault', 'energy', 'put', 'thousands', 'americans', 'work']
#
#
# ['we', 'abortions', 'texas', 'every', 'year']
#
#
# ['says', 'shows', 'potential', 'problems', 'investing', 'rail']
#
#
# ['says', 'senate', 'rival', 'tommy', 'thompson', 'big', 'corporate', 'lobbyist', 'lobbying', 'middle', 'campaign']
#
#
# ['congressman', 'paul', 'introduces', 'numerous', 'pieces', 'substantive', 'legislation', 'year', 'probably', 'single', 'member', 'congress']
#
#
# ['four', 'members', 'rhode', 'island', 'general', 'assembly', 'went', 'vote', 'told', 'already', 'voted']
#
#
# ['the', 'health', 'care', 'reform', 'plan', 'require', 'americans', 'subsidize', 'abortion', 'tax', 'dollars']
#
#
# ['mark', 'warner', 'cast', 'tiebreaking', 'vote', 'pass', 'obamacare']
#
#
# ['in', 'iraq', 'violence', 'low', 'since', 'start', 'war']
#
#
# ['north', 'koreas', 'missiles', 'going', 'capability', 'reach', 'united', 'states', 'anytime', 'real', 'soon']
#
#
# ['im', 'running', 'office', 'much', 'experience', 'qualifications', 'barack', 'obama', 'ran']
#
#
# ['says', 'measure', 'cost', 'fortune', 'elections', 'measure', 'cost', 'less']
#
#
# ['in', 'charlie', 'crist', 'applauded', 'pick', 'sarah', 'palin', 'said', 'would', 'great', 'job']
#
#
# ['the', 'president', 'promised', 'close', 'space', 'gap', 'seems', 'intent', 'repeating', 'events', 'created', 'space', 'gap', 'first', 'place', 'putting', 'place', 'new', 'rocket', 'design', 'trying', 'underfund', 'effort']
#
#
# ['republicans', 'dont', 'think', 'good', 'idea', 'make', 'child', 'care', 'tax', 'credit', 'stronger']
#
#
# ['more', 'half', 'women', 'give', 'birth', 'outside', 'marriage']
#
#
# ['i', 'cut', 'spending', 'serving', 'state', 'legislature']
#
#
# ['if', 'ban', 'practice', 'earmarks', 'could', 'save', 'american', 'taxpayer', 'anywhere', 'billion', 'billion', 'dollars', 'year', 'spending']
#
#
# ['our', 'welfare', 'system', 'consumes', 'percent', 'budget']
#
#
# ['agriculture', 'strongest', 'industry', 'ohio']
#
#
# ['this', 'first', 'time', 'history', 'weve', 'raising', 'debt', 'limit', 'also', 'spending', 'cuts']
#
#
# ['sarah', 'palin', 'repeating', 'abraham', 'lincoln', 'words', 'discussing', 'war', 'iraq']
#
#
# ['kelly', 'ayotte', 'voted', 'budget', 'billion', 'cuts', 'pell', 'grants']
#
#
# ['says', 'connie', 'mack', 'iv', 'passed', 'one', 'bill', 'seven', 'years']
#
#
# ['states', 'get', 'federal', 'dollars', 'pay', 'taxes']
#
#
# ['barack', 'obama', 'said', 'basically', 'agreed', 'way', 'george', 'bush', 'conducting', 'war']
#
#
# ['says', 'president', 'barack', 'obama', 'socialist']
#
#
# ['wisconsin', 'literally', 'broke', 'republicans', 'took', 'office', 'january']
#
#
# ['about', 'medicaid', 'beneficiaries', 'children', 'account', 'programs', 'cost', 'elderly', 'account', 'cost']
#
#
# ['says', 'tom', 'cottons', 'vote', 'congress', 'change', 'medicare', 'increase', 'expenses', 'every', 'senior', 'arkansas']
#
#
# ['says', 'obama', 'administration', 'approved', 'major', 'disaster', 'declaration', 'oklahoma', 'nine', 'states', 'counties', 'burned', 'three', 'days', 'texas', 'wildfires', 'burning', 'longer', 'without', 'declaration']
#
#
# ['our', 'campaign', 'depends', 'small', 'donations', 'majority', 'support']
#
#
# ['says', 'crist', 'campaign', 'website', 'eliminated', 'references', 'republican', 'party']
#
#
# ['on', 'plan']
#
#
# ['there', 'hasnt', 'really', 'lot', 'net', 'growth', 'federal', 'workforce', 'compare', 'say']
#
#
# ['the', 'american', 'conservative', 'union', 'gives', 'tim', 'ryan', 'dismal', 'percent', 'rating', 'billions', 'contributed', 'national', 'debt']
#
#
# ['the', 'departments', 'commerce', 'education', 'energy', 'epa', 'saw', 'spending', 'increase', 'percent', 'percent']
#
#
# ['says', 'hasnt', 'changed', 'view', 'abortion', 'restrictions']
#
#
# ['says', 'director', 'group', 'receiving', 'texas', 'grant', 'provide', 'womens', 'health', 'services', 'believes', 'hiv', 'spread', 'sewer', 'system']
#
#
# ['says', 'rick', 'perry', 'texas', 'governor', 'relied', 'stimulus', 'funds', 'close', 'states', 'budget', 'deficit']
#
#
# ['democrats', 'cutting', 'school', 'funding', 'four', 'times', 'last', 'years', 'came', 'office']
#
#
# ['says', 'president', 'barack', 'obama', 'granted', 'waivers', 'allowing', 'united', 'states', 'refugees', 'provided', 'material', 'support', 'terrorists']
#
#
# ['in', 'almost', 'every', 'country', 'world', 'artists', 'musicians', 'paid', 'music', 'played', 'radio', 'in', 'fact', 'countries', 'besides', 'right', 'china', 'iran', 'north', 'korea']
#
#
# ['one', 'man', 'sacrificed', 'country', 'one', 'man', 'opposed', 'flawed', 'strategy', 'iraq', 'one', 'man', 'courage', 'call', 'change', 'one', 'man', 'play', 'politics', 'truth', 'one', 'man', 'stands', 'special', 'interests']
#
#
# ['says', 'paul', 'ryan', 'supports', 'banning', 'abortions', 'even', 'cases', 'rape', 'incest']
#
#
# ['more', 'american', 'soldiers', 'lost', 'lives', 'afghanistan', 'last', 'months', 'this', 'combined', 'total', 'nine', 'years']
#
#
# ['weve', 'doubled', 'production', 'clean', 'energy']
#
#
# ['most', 'americans', 'support', 'legalization', 'marijuana']
#
#
# ['under', 'barack', 'obama', 'lowest', 'workforce', 'since', 'president', 'jimmy', 'carter']
#
#
# ['a', 'rural', 'hospital', 'missouri', 'closes', 'every', 'months', 'the', 'legislatures', 'failure', 'expand', 'medicaid', 'brought', 'crisis', 'many', 'missouris', 'rural', 'health', 'care', 'providers']
#
#
# ['harambe', 'received', 'votes', 'presidential', 'election']
#
#
# ['the', 'united', 'states', 'one', 'seven', 'nations', 'allows', 'elective', 'abortions', 'weeks']
#
#
# ['says', 'thom', 'tillis', 'gives', 'tax', 'breaks', 'yacht', 'jet', 'owners']
#
#
# ['during', 'time', 'house', 'speaker', 'unemployment', 'came', 'percent', 'percent']
#
#
# ['obamacare', 'republican', 'plan', 'early']
#
#
# ['we', 'amendment', 'health', 'care', 'law', 'said', 'federal', 'government', 'going', 'take', 'education']
#
#
# ['assembly', 'democrats', 'wanted', 'raise', 'gas', 'tax', 'billion', 'we', 'said', 'ground', 'theyre', 'sweating', 'theyre', 'twitching', 'its', 'ugly', 'cause', 'i', 'keep', 'saying']
#
#
# ['says', 'turned', 'medicaid', 'expansion', 'obamacare', 'actions', 'took', 'first', 'time', 'wisconsins', 'history', 'everyone', 'living', 'poverty', 'covered', 'medicaid']
#
#
# ['says', 'patrick', 'murphy', 'switched', 'vote', 'all', 'aboard', 'florida', 'father', 'tried', 'get', 'bid', 'build', 'unsuccessful']
#
#
# ['says', 'sen', 'sherrod', 'brown', 'promised', 'first', 'stimulus', 'bill', 'would', 'fund', 'brent', 'spence', 'bridge']
#
#
# ['tampa', 'got', 'federal', 'housing', 'money', 'scored', 'higher', 'blight', 'scoring', 'system', 'theyve', 'got', 'much', 'bigger', 'problem']
#
#
# ['in', 'nine', 'democratic', 'debates', 'weve', 'one', 'question', 'womans', 'right', 'make', 'decisions', 'reproductive', 'health', 'care', 'one', 'question']
#
#
# ['the', 'amendment', 'would', 'criminalized', 'certain', 'private', 'transfers', 'firearms', 'honest', 'citizens', 'requiring', 'lifelong', 'friends', 'neighbors', 'family', 'members', 'get', 'government', 'approval']
#
#
# ['mccain', 'trying', 'have', 'both', 'ways', 'iraq']
#
#
# ['the', 'budget', 'submitted', 'obama', 'add', 'debt', 'outstanding', 'debt', 'previous', 'presidents', 'combined']
#
#
# ['i', 'issued', 'moratorium', 'deepwater', 'drilling']
#
#
# ['toomey', 'trump', 'ban', 'abortion', 'punish', 'women']
#
#
# ['tuition', 'rutgers', 'increased', 'percent', 'since', 'gov', 'chris', 'christie', 'took', 'office', 'cut', 'funding', 'higher', 'education']
#
#
# ['the', 'reason', 'even', 'colleges', 'point', 'politicians', 'said', 'you', 'know', 'we', 'start', 'colleges']
#
#
# ['capital', 'metro', 'originally', 'said', 'metrorails', 'yearly', 'operating', 'costs', 'would', 'million', 'last', 'year', 'cost', 'million', 'operate']
#
#
# ['providence', 'pension', 'fund', 'invested', 'hedge', 'funds', 'less', 'transparent', 'state']
#
#
# ['says', 'president', 'john', 'kennedy', 'released', 'star', 'green', 'bay', 'packer', 'military', 'reserve', 'duty', 'could', 'play', 'nfl', 'championship', 'game']
#
#
# ['if', 'general', 'assembly', 'address', 'states', 'structural', 'deficit', 'education', 'professionals', 'immediately', 'yanked', 'pennsylvania', 'schools']
#
#
# ['says', 'brought', 'jobs', 'texas', 'moving', 'factories', 'china']
#
#
# ['paul', 'broun', 'authored', 'legislation', 'adopted', 'congress']
#
#
# ['on', 'recess', 'appointments']
#
#
# ['four', 'years', 'congressman', 'hank', 'johnson', 'never', 'talked', 'marta']
#
#
# ['texas', 'highest', 'rate', 'uninsured', 'nation', 'and', 'uninsured', 'children', 'texas', 'state']
#
#
# ['eighty', 'percent', 'wall', 'street', 'executives', 'spouses', 'donations', 'go', 'democrats']
#
#
# ['like', 'scott', 'walker', 'opposed', 'transportation', 'bill', 'billion', 'wasteful', 'spending']
#
#
# ['newspapers', 'say', 'florida', 'made', 'bad', 'investments', 'lost', 'hundreds', 'millions', 'dollars', 'billions', 'pension', 'funds', 'lost', 'who', 'charge', 'floridas', 'investments', 'alex', 'sink']
#
#
# ['says', 'percent', 'health', 'care', 'dollars', 'spent', 'percent', 'population']
#
#
# ['steve', 'southerland', 'pay', 'taxes']
#
#
# ['eliminating', 'obamacare', 'saves', 'billion', 'year']
#
#
# ['there', 'percent', 'virginians', 'minimum', 'wage', 'earners', 'years', 'age', 'working', 'trying', 'raise', 'family']
#
#
# ['says', 'broken', 'compact', 'fluorescent', 'light', 'bulbs', 'allegedly', 'cause', 'migraines', 'epilepsy', 'attacks']
#
#
# ['at', 'least', 'quarter', 'apprehended', 'border', 'criminal', 'records']
#
#
# ['says', 'rick', 'scotts', 'record', 'jobs', 'includes', 'florida', 'ranked', 'nation', 'unemployment']
#
#
# ['says', 'president', 'obamas', 'new', 'immigration', 'plan', 'amnesty']
#
#
# ['for', 'first', 'time', 'years', 'republicansdont', 'hold', 'single', 'statewide', 'office', 'virginia']
#
#
# ['polls', 'show', 'americans', 'overwhelmingly', 'support', 'expanding', 'background', 'checks']
#
#
# ['nearly', 'residents', 'born', 'abroad']
#
#
# ['when', 'comes', 'jobless', 'workers', 'mitt', 'romney', 'says', 'likes', 'fire', 'people']
#
#
# ['a', 'child', 'born', 'america', 'today', 'inherit', 'million', 'debt', 'moment', 'theyre', 'placed', 'mothers', 'arms']
#
#
# ['says', 'fleet', 'attack', 'submarines', 'scheduled', 'fall', 'boats', 'navy', 'says', 'needs', 'carry', 'current', 'missions']
#
#
# ['georgias', 'share', 'money', 'federal', 'highway', 'trust', 'fund', 'declined', 'percent']
#
#
# ['americans', 'spend', 'hours', 'year', 'filling', 'forms', 'fafsa', 'that', 'equivalent', 'jobs']
#
#
# ['if', 'look', 'application', 'security', 'clearance', 'i', 'clearance', 'even', 'president', 'united', 'states', 'obtain', 'background']
#
#
# ['says', 'hawaii', 'gov', 'neil', 'abercrombie', 'made', 'visit', 'kinkos', 'forge', 'president', 'barack', 'obamas', 'birth', 'certificate', 'two', 'days', 'obama', 'unveiled', 'media']
#
#
# ['in', 'illinois', 'legislature', 'barack', 'obama', 'voted', 'instead', 'yes', 'seven', 'votes', 'involving', 'abortion', 'rights']
#
#
# ['if', 'want', 'vote', 'texas', 'use', 'permit', 'valid', 'form', 'identification', 'valid', 'student', 'id', 'isnt', 'good', 'enough']
#
#
# ['says', 'cascading', 'effects', 'climate', 'change', 'contributed', 'rise', 'isis']
#
#
# ['says', 'state', 'sandy', 'pasch', 'recall', 'opponent', 'voted', 'allow', 'public', 'school', 'employees', 'use', 'taxpayer', 'dollars', 'pick', 'tab', 'forviagra']
#
#
# ['barack', 'obama', 'rejects', 'everyone', 'white', 'including', 'mother', 'grandparents']
#
#
# ['a', 'company', 'hired', 'common', 'core', 'testing', 'florida', 'attract', 'every', 'one', 'children', 'become', 'homosexual', 'possibly']
#
#
# ['the', 'supreme', 'court', 'traditionally', 'asked', 'lot', 'questions', 'oral', 'arguments']
#
#
# ['fracturing', 'horizontally', 'fracturing', 'shale', 'open', 'larger', 'pockets', 'natural', 'gas', 'used', 'years', 'wells', 'fracked', 'ohio']
#
#
# ['in', 'percent', 'households', 'getting', 'percent', 'income', 'federal', 'government', 'another', 'percent', 'receiving', 'almost', 'percent']
#
#
# ['we', 'eighth', 'nation', 'job', 'creation', 'no', 'midwest']
#
#
# ['in', 'europe', 'church', 'attendance', 'rates', 'single', 'digits', 'churches', 'supported', 'taxes']
#
#
# ['says', 'george', 'lemieux', 'even', 'compared', 'marco', 'rubio', 'barack', 'obama']
#
#
# ['says', 'barack', 'obama', 'promised', 'halve', 'deficit', 'first', 'term']
#
#
# ['says', 'government', 'gotten', 'tarp', 'money', 'back', 'plus', 'profit']
#
#
# ['points', 'light', 'worlds', 'largest', 'volunteer', 'organization']
#
#
# ['says', 'mark', 'pryorcut', 'medicare', 'pay', 'obamacare']
#
#
# ['says', 'tim', 'kaine', 'actually', 'tried', 'raise', 'taxes', 'billion']
#
#
# ['says', 'marco', 'rubio', 'proposing', 'new', 'trillion', 'welfare', 'program', 'tax', 'credits', 'trillion', 'new', 'military', 'spending']
#
#
# ['i', 'senator', 'turned', 'state', 'pension', 'plan', 'legislators']
#
#
# ['female', 'buffalo', 'lead', 'herd']
#
#
# ['there', 'system', 'vet', 'refugees', 'middle', 'east']
#
#
# ['says', 'chris', 'christies', 'plan', 'economy', 'propose', 'income', 'tax', 'cut', 'disproportionately', 'benefits', 'wealthy', 'hes', 'still', 'proposing']
#
#
# ['obama', 'used', 'million', 'federal', 'money', 'emmigrate', 'sic', 'hamas', 'refugees', 'usa']
#
#
# ['on', 'offshore', 'drilling']
#
#
# ['we', 'came', 'white', 'house', 'dead', 'broke', 'debt']
#
#
# ['i', 'think', 'seven', 'eight', 'california', 'system', 'universities', 'dont', 'even', 'teach', 'american', 'history', 'course', 'its', 'even', 'available', 'taught']
#
#
# ['bob', 'menendez', 'voted', 'enact', 'new', 'tax', 'sale', 'homes']
#
#
# ['says', 'budget', 'provides', 'highest', 'state', 'funding', 'level', 'history', 'education']
#
#
# ['ive', 'almost', 'every', 'day']
#
#
# ['in', 'early', 'edward', 'kennedy', 'secretly', 'offered', 'help', 'soviet', 'leaders', 'counter', 'reagan', 'administrations', 'position', 'nuclear', 'disarmament']
#
#
# ['says', 'epa', 'permit', 'languished', 'strickland', 'new', 'epa', 'director', 'got', 'done', 'two', 'days']
#
#
# ['says', 'governor', 'going', 'around', 'state', 'talking', 'fund', 'income', 'tax', 'cut', 'benefits', 'higher', 'income', 'earners', 'lower', 'income', 'earners']

# %%
filt[1]
# Out:
# 'wisconsin,pace,double,number,layoffs,year'

# %%
df['text'] = filt

# %%
df.to_csv('test.csv',index=False)
